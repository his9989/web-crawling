# %%
import pandas as pd

import matplotlib.pyplot as plt
import requests
import urllib.request
import json
import requests
import re
from bs4 import BeautifulSoup

url = "https://play.google.com/store/getreviews?authuser=0"
id = 'kr.goodchoice.abouthere'
token = 'ZLqR3TmB64y6koyq8uj1tqqiQ4k:14191636750027'


# Review가지고오기.
def GetReviews(url, id, token, pages):
    param = {'reviewType': '0', 'pageNum': '10000', 'id': '', 'reviewSortOrder': '4', 'xhr': '1', 'token': '',
             'hl': 'ko'}
    param['id'] = id
    param['token'] = token

    review_date_all = []
    review_star_all = []
    review_user_all = []
    review_title_all = []
    review_body_all = []
    for i in range(1, pages):
        param['pageNum'] = i
        res = requests.post(url, data=param)
        print(" line : {line}, code : {code}".format(line=i, code=res.status_code))
        if res.status_code == 400 or i == pages - 1:
            review_df = pd.DataFrame(
                {'DATE': review_date_all, 'STAR': review_star_all, 'TITLE': review_title_all, 'USER': review_user_all,
                 'BODY': review_body_all})
            columns_list = ['DATE', 'USER', 'STAR', 'TITLE', 'BODY']
            return (review_df[columns_list])
        else:
            body = res.text[6:]
            res_json = json.loads(body)
            bs = BeautifulSoup(res_json[0][2], 'html.parser')
            review_lists = bs.find_all('div', class_="single-review")
            for j in range(1, len(review_lists)):
                review_date = review_lists[j].find('span', class_="review-date").text  # review_date
                review_star = int(re.findall(r'\d+', review_lists[0].find('div',
                                                                          class_="tiny-star star-rating-non-editable-container")[
                    'aria-label'])[1])  # Get Digits from Rates
                review_title = review_lists[j].find('span', class_="review-title").text  # title
                review_body = review_lists[j].find('div', class_="review-body with-review-wrapper").text  # review body
                review_body = str.replace(review_body, review_title, "")
                review_body = str.replace(review_body, "전체 리뷰", "")
                review_body = review_body.strip()
                review_user = review_lists[j].find('span', class_="author-name").text.strip()  # get Reviewer
                review_date_all.append(review_date)
                review_star_all.append(review_star)
                review_user_all.append(review_user)
                review_title_all.append(review_title)
                review_body_all.append(review_body)

DF = GetReviews(url,id,token,5)
print(DF)
# Out:
#  line : 1, code : 200
#  line : 2, code : 200
#  line : 3, code : 200
#  line : 4, code : 200
#              DATE            USER  STAR TITLE  \
# 0    2018년 1월 17일      JUNSUK BAE     1
# 1    2018년 1월 17일             연성훈     1
# 2    2018년 1월 23일             권혁인     1
# 3    2018년 1월 27일             변우진     1
# 4    2018년 1월 16일             서호준     1
# 5    2018년 1월 19일             이찬호     1
# 6    2018년 1월 19일                     1
# 7    2018년 1월 23일             김영완     1
# 8    2018년 1월 19일                     1
# 9    2018년 1월 24일              김호     1
# 10   2018년 1월 28일             김석진     1
# 11   2018년 1월 17일             강호일     1
# 12   2018년 1월 18일             박세정     1
# 13   2018년 1월 18일             공명진     1
# 14   2018년 1월 20일             김선유     1
# 15   2018년 1월 24일             라오스     1
# 16   2018년 1월 17일             김철규     1
# 17   2018년 1월 27일             감자탕     1
# 18   2018년 1월 26일             김홍철     1
# 19   2018년 1월 21일             이재일     1
# 20   2018년 1월 20일                     1
# 21   2018년 1월 20일             조세영     1
# 22   2018년 1월 24일             장인호     1
# 23   2018년 1월 26일                     1
# 24   2018년 1월 23일             김성용     1
# 25   2018년 1월 24일             김정태     1
# 26   2018년 1월 19일             김용운     1
# 27   2018년 1월 18일             이장미     1
# 28   2018년 1월 20일             이석우     1
# 29   2018년 1월 22일             조수진     1
# ..            ...             ...   ...   ...
# 87   2018년 1월 21일                     5
# 88   2018년 1월 20일             오진형     5
# 89   2018년 1월 23일             한재혁     5
# 90   2018년 1월 24일          쌍문동돌고래     5
# 91   2018년 1월 25일             김동현     5
# 92   2018년 1월 26일             이원석     5
# 93   2018년 1월 26일             이병구     5
# 94   2018년 1월 17일             이대윤     5
# 95   2018년 1월 16일             김진권     5
# 96   2018년 1월 19일             이지석     5
# 97   2018년 1월 20일             문혜인     5
# 98   2018년 1월 21일              현규     5
# 99   2018년 1월 22일             박준일     5
# 100  2018년 1월 17일           유링T v     5
# 101  2018년 1월 17일             한현석     5
# 102  2018년 1월 20일  Seok Young Lee     5
# 103  2018년 1월 22일                     5
# 104  2018년 1월 18일             한대균     5
# 105  2018년 1월 18일             길주명     5
# 106  2018년 1월 22일             우대성     5
# 107  2018년 1월 23일             석승균     5
# 108  2018년 1월 23일             김유진     5
# 109  2018년 1월 24일                     5
# 110  2018년 1월 24일      Jun Ho Lee     5
# 111  2018년 1월 26일                     5
# 112  2018년 1월 25일             이인호     5
# 113  2018년 1월 25일             김준현     5
# 114  2018년 1월 25일             김준식     5
# 115  2018년 1월 26일             박종화     5
# 116  2018년 1월 27일            고고현수     5
#
#                                                   BODY
# 0    좋아보이는곳 많아보여 좋아요 자주여행  다니는데  이제야  어플써보네요ㅎ 후기 많이...
# 1                    무슨 앱이 한번씩 켜집니까 ㅡㅡ 특히나 민감한 업종인데 ㅡㅡ
# 2                                 처음으로 해봤네요 자주 이용하겠습니다
# 3                            앱들 다 깔아 써봤눈데 이거보다 좋은앱없어요~
# 4    다 좋은데... 예약 도중 휴대폰 홈키 눌러서 나갔다오면 자꾸 예약중이던거 다 없어...
# 5                      전체적으로 좋아요 다만 욕실들 사진들도 많았으면 좋겠어요
# 6                                만원.오천원쿠폰 제대로 사용함  짱!ㅋ
# 7                       평창때문에 짜증나지만 숙박어플중에 최고라는건 변함없어요
# 8    머리털나고 리뷰처음남겨용ㅎㅎ 타사는 객실사진만보여서 불편했는데 여기어때는 vr기능이...
# 9        자주 이용하고 있습니다.  앞으로 높은 보안을 바탕으로 운영을 하시면 좋겠습니다.
# 10                   누구 맘대로 자동이체가 걸려 ㅡㅡ 신청한적도 없는데 장난치나
# 11                                  실속있게 숙소 찾을수 있어 좋아요
# 12               처음 써보는데 나름 좋아요 걱정반 모두 날리고 잘 이용 하고 있어요
# 13                                타숙소앱쓰다가갈아탔는데괜찮은것같아요.
# 14   쿠폰혜택도 좋고 포인트도있어서 참좋네요~! 자주 이용하겠습니다♡♡ 좋은 이벤트 많이...
# 15                   절차가 복잡하긴 하지만 편하게 예약하고 가니까 좋은거 같네요
# 16   리뷰를 보면서 시설이 더 좋고 괜찮은 숙소를 찾을수있는 어플이 있어서 참편하고 좋습...
# 17                 인증번호 자꾸 틀리다고 뜨는데 어떻게 가입하라는거냐 개같네 진짜
# 18                           네이버페이 연동되는게 가장 마음에드네요'~'/
# 19                 가입하고 쿠폰등등으로 할인많이받네요 예약도 간편하고 잘쓰고갑니다
# 20                                          잘이용하고있습니다~
# 21                            비교도 좋고 할인도 좋고 편하구 좋아요 ㅎㅎ
# 22               좋아요  다른데랑 비슷하긴한데 가끔 잘 찾아보면 꿀혜택도 많아요^^
# 23                 결제도 간편하고 좋은가격으로 편하게 쉬다가 올수 있어서 좋습니다
# 24                                숙소 잘 보고 올렸으면 더러운곳 많음
# 25                                       가격이  야놀자보다 비쌈
# 26                          예약하기 편리하네요 ㅋ 잘 사용하고 잇습니다 ㅋ
# 27                                             사용이 편해요
# 28                                  처음 사용하는데 기대가 많이되네요
# 29                                       쿠폰도쓰고 간단하고좋아요
# ..                                                 ...
# 87                                                굿이네요
# 88                                               너무좋아요
# 89                                             편하고 좋네요
# 90                                             편하구 좋아요
# 91                                               편리하네요
# 92                                              빠르고 쉽네
# 93                                                편리해요
# 94                                                  굳굳
# 95                                                  간편
# 96                                                 좋아요
# 97                                                 좋아요
# 98                                               좋아용~♡
# 99                                                좋아요.
# 100                                                좋아요
# 101                                                 좋음
# 102                                                좋네요
# 103                                                좋아요
# 104                                                좋네요
# 105                                                좋아요
# 106                                                 굿굿
# 107                                                좋네요
# 108                                                좋아요
# 109                                                 최고
# 110                                                좋네요
# 111                                                 굿굿
# 112                                                좋아요
# 113                                                좋아요
# 114                                                좋아요
# 115                                                좋아요
# 116                                                 홧팅
#
# [117 rows x 5 columns]
